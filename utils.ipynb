# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from gensim.models import Word2Vec

# %%
model = Word2Vec.load('./word2vec_baike')

# %%
'''
从txt文件中读取词表
'''
def buildVocabFromFile(filename):
    word_list = []
    with open(filename, encoding='utf-8') as f:
        for word in f.readlines():
            word = word.strip()
            word_list.append(word)
    return word_list

# %%
'''
词表去重
'''
def uniquify(word_list):
    return set(word_list)

# %%
'''
合并两个词表，并排序
'''
def mergeWordlist(word_list1, word_list2):
    word_list = word_list1 + word_list2
    return set(word_list)

# %%
'''
通过词表读入词向量
'''
def buildWordVec(word_list):
    wv = []
    unmap_list = []
    for word in word_list:
        if word not in model.wv.vocab:
            unmap_list.append(word)
        else:
            wv.append(model[word])
    print(f'{len(unmap_list)} words are not in the model.')
    return np.array(wv), unmap_list

# %%
l = buildVocabFromFile('./class/animals.txt')

# %%
l
# Out:
# ['狗',
#  '猫',
#  '恐龙',
#  '鸡',
#  '大象',
#  '蚊子',
#  '蛇',
#  '蚂蚁',
#  '狮子',
#  '蜘蛛',
#  '蜜蜂',
#  '鲸鱼',
#  '野生动物',
#  '大熊猫',
#  '黑猩猩',
#  '蝙蝠',
#  '猪',
#  '鳄鱼',
#  '老鼠',
#  '老虎',
#  '鹦鹉',
#  '马',
#  '蟑螂',
#  '海豚',
#  '猴子',
#  '鲨鱼',
#  '乌龟',
#  '牛',
#  '章鱼',
#  '兔子',
#  '苍蝇',
#  '蝉',
#  '长颈鹿',
#  '狼',
#  '青蛙',
#  '北极熊',
#  '蝴蝶',
#  '蜥蜴',
#  '仓鼠',
#  '蜗牛',
#  '鸽子',
#  '羊',
#  '蟒蛇',
#  '犀牛',
#  '金鱼',
#  '麻雀',
#  '猫头鹰',
#  '萤火虫',
#  '乌鸦',
#  '变色龙',
#  '龙猫',
#  '猛犸象',
#  '水母',
#  '蜻蜓',
#  '龙虾',
#  '企鹅',
#  '蚕',
#  '狐狸',
#  '猩猩',
#  '果蝇',
#  '螃蟹',
#  '食人鱼',
#  '熊',
#  '松鼠',
#  '蚯蚓',
#  '虎鲸',
#  '螳螂',
#  '蜈蚣',
#  '翠鸟',
#  '知了',
#  '眼镜蛇',
#  '斑胸草雀',
#  '穿山甲',
#  '驯鹿',
#  '海蛞蝓',
#  '大猩猩',
#  '乌贼',
#  '骆驼',
#  '海马',
#  '袋鼠',
#  '海龟',
#  '刺猬',
#  '电鳗',
#  '树懒',
#  '绵羊',
#  '河马',
#  '玳瑁',
#  '蜂鸟',
#  '斑鳖',
#  '蝎子',
#  '浣熊',
#  '豹子',
#  '河豚',
#  '藏獒',
#  '野猪',
#  '蟋蟀',
#  '燕子',
#  '伊犁鼠兔',
#  '鸭子',
#  '啄木鸟',
#  '蓝鲸',
#  '屎壳郎',
#  '三文鱼',
#  '海狮',
#  '海鸥',
#  '倭黑猩猩',
#  '黑熊',
#  '海鸟',
#  '螳螂虾',
#  '秃鹫',
#  '裸鼹鼠',
#  '水熊虫',
#  '燕隼',
#  '奶牛',
#  '雪豹',
#  '猎豹',
#  '白鲸',
#  '仙女虾',
#  '狒狒',
#  '锯鳐',
#  '火鸡',
#  '白蚁',
#  '海蟾蜍',
#  '猕猴',
#  '中华鲟',
#  '山羊',
#  '非洲肺鱼',
#  '鸵鸟',
#  '寄生虫',
#  '壁虎',
#  '象龟',
#  '鱿鱼',
#  '毛虫',
#  '冬虫夏草',
#  '候鸟',
#  '朱鹮',
#  '信天翁',
#  '麋鹿',
#  '帝企鹅',
#  '鹦鹉螺',
#  '豪猪',
#  '棕熊',
#  '珊瑚',
#  '牦牛',
#  '黑脉金斑蝶',
#  '阳彩臂金龟',
#  '箭毒蛙',
#  '鲎',
#  '美人鱼',
#  '秋刀鱼',
#  '金蝉',
#  '斑马鱼',
#  '蟾蜍',
#  '螨虫',
#  '牡蛎',
#  '军舰鸟',
#  '寄生蜂',
#  '疣猪',
#  '海牛',
#  '火烈鸟',
#  '锤头鲨',
#  '母鸡',
#  '鹰',
#  '熊猫',
#  '信鸽',
#  '老鹰',
#  '鹿',
#  '白犀牛',
#  '河狸',
#  '鲶鱼',
#  '座头鲸',
#  '霸王龙',
#  '狼蛛',
#  '食草动物',
#  '海象',
#  '蛞蝓',
#  '高鼻羚羊',
#  '蝾螈',
#  '月鱼',
#  '孔雀鱼',
#  '飞蛾',
#  '杜鹃',
#  '食骨蠕虫',
#  '羚羊',
#  '水蛭',
#  '帝王蝶',
#  '渡渡鸟',
#  '露脊鲸',
#  '中华锦绣龙虾',
#  '板足鲎',
#  '鹦鹉鱼',
#  '抹香鲸',
#  '蜂鸟鹰蛾',
#  '墨西哥丽脂鲤',
#  '类人猿',
#  '鬣狗',
#  '马陆',
#  '沙猫',
#  '熊蜂',
#  '鲸鲨',
#  '血吸虫',
#  '狨猴',
#  '砗磲',
#  '跳鼠',
#  '射水鱼',
#  '栉水母',
#  '公鸡',
#  '碎毛盘海蛞蝓',
#  '斑马',
#  '蚜虫',
#  '千足虫',
#  '野猫',
#  '双髻鲨',
#  '海獭',
#  '捕鱼蛛',
#  '弹涂鱼',
#  '戴胜',
#  '飞猫',
#  '独角鲸',
#  '犰狳',
#  '始祖鸟',
#  '帽贝',
#  '水螅',
#  '小蓝企鹅',
#  '沧龙',
#  '翻车鱼',
#  '响尾蛇',
#  '行军蚁',
#  '负鼠',
#  '雪貂',
#  '美洲鳗',
#  '洞狮',
#  '蛐蛐',
#  '蝈蝈',
#  '金龙鱼',
#  '须翡翠',
#  '鹅',
#  '切叶蚁',
#  '三叶虫',
#  '虱子',
#  '滇金丝猴',
#  '磷虾',
#  '遗鸥',
#  '长毛象',
#  '水熊',
#  '奇翼龙',
#  '灰熊',
#  '小熊猫',
#  '六须鲶鱼',
#  '狐猴',
#  '杜兹肺鱼',
#  '海燕',
#  '蛔虫',
#  '画眉',
#  '娃娃鱼',
#  '草鱼',
#  '淡水鱼',
#  '海参',
#  '白颊林莺',
#  '海豹',
#  '蛇颈龙',
#  '毛毛虫',
#  '蝌蚪',
#  '土拔鼠',
#  '逆戟鲸',
#  '非洲灰鹦鹉',
#  '红点齿蟾',
#  '水牛',
#  '扇贝',
#  '魟鱼',
#  '海绵',
#  '泰迪',
#  '象拔蚌',
#  '海星',
#  '布谷鸟',
#  '巨猿',
#  '织纹螺',
#  '中华鳖',
#  '喜鹊',
#  '加拉帕戈斯象龟',
#  '红腹锦鸡',
#  '赛加羚羊',
#  '海月水母',
#  '暴龙',
#  '豹猫',
#  '鲤鱼',
#  '攀鲈鱼',
#  '臭虫',
#  '跳蚤',
#  '大黄蜂',
#  '吉娃娃',
#  '粉红珊瑚鳌虾',
#  '虎头蜂',
#  '蜘蛛蟹',
#  '红珊瑚',
#  '水獭',
#  '大王具足虫',
#  '小葵花凤头鹦鹉',
#  '亚洲象',
#  '弥曼始今鸟',
#  '白颊山雀',
#  '帆水母',
#  '斯瓦尔巴驯鹿',
#  '沙漠穹蛛',
#  '太平洋潜泥蛤',
#  '金毛',
#  '龙',
#  '纽虫',
#  '四川短翅莺',
#  '放屁虫',
#  '啄羊鹦鹉',
#  '北美负鼠',
#  '射炮步甲',
#  '鸊鷉',
#  '智利龙',
#  '绿鬣蜥',
#  '火玫瑰蜘蛛',
#  '云猫',
#  '东北虎',
#  '口袋鲨',
#  '婆罗洲犀牛',
#  '震旦鸦雀',
#  '麦蚜',
#  '玻璃蛙',
#  '貉',
#  '巨脉蜻蜓',
#  '鼓虾',
#  '大银鱼',
#  '绿毛龟',
#  '鳞角腹足蜗牛',
#  '野狼',
#  '禾花雀',
#  '鳜鱼',
#  '羚牛',
#  '黑犀牛',
#  '椋鸟',
#  '白颏海燕',
#  '扁头摄魂蜂',
#  '中华花龟',
#  '旅鼠',
#  '桶水母',
#  '贻贝',
#  '红嘴相思鸟',
#  '吸血蝙蝠',
#  '巨型蜘蛛蟹',
#  '跳蛛',
#  '齿猛蚁',
#  '蜜獾',
#  '毛丝鼠',
#  '陷阱颚蚁',
#  '颚口线虫',
#  '红树林树雀',
#  '高智商动物',
#  '大鼠',
#  '布偶猫',
#  '黄鹂',
#  '羞死鸟',
#  '甲鱼',
#  '多鳍鱼',
#  '赛马',
#  '弓形虫',
#  '复变甲',
#  '螳水蝇',
#  '钩翅石蛾',
#  '旌蛉',
#  '蚊蝎蛉',
#  '鸭嘴兽',
#  '普尔加托里猴',
#  '貘',
#  '蜱虫',
#  '变形蛙',
#  '褐飞虱',
#  '果壳綦江龙',
#  '猎鹰',
#  '隐尾蠊',
#  '吸血鬼蟹',
#  '猿猴',
#  '腔棘鱼',
#  '孔雀跳蛛',
#  '红色动物',
#  '盔犀鸟',
#  '透明鱼',
#  '沟齿鼩',
#  '安第斯眼镜熊',
#  '线虫',
#  '缅因猫',
#  '火体虫',
#  '南美洲栗鼠',
#  '奇异多指节蛙',
#  '驴',
#  '冈比亚鼠',
#  '白头鹫',
#  '地中海实蝇',
#  '阿马乌童蛙',
#  '大角羊',
#  '假鳃鳉鱼',
#  '德国蜚蠊',
#  '美洲蜚蠊',
#  '龙王鲸',
#  '吸血虫',
#  '白兔',
#  '虫',
#  '刺背鳄蜥',
#  '灰鲸',
#  '雷龙',
#  '兰花螳螂',
#  '猫猴',
#  '短尾猫',
#  '新疆北鲵',
#  '突灶螽',
#  '灶马',
#  '燕八哥',
#  '穴居沙龟',
#  '家兔',
#  '大雁',
#  '田猫狸',
#  '大鲵',
#  '查菲窄尾魟',
#  '苏格兰牧羊犬',
#  '安哥拉兔',
#  '加拉帕格斯巨人蜈蚣',
#  '枯叶蝴蝶',
#  '白色鼠海豚',
#  '隐翅虫',
#  '石鳖',
#  '大山雀',
#  '盲蛇',
#  '香港后棱蛇',
#  '白鹮',
#  '颌针鱼',
#  '鬣鳞蜥',
#  '科莫多巨蜥',
#  '虎皮鹦鹉',
#  '金丝熊',
#  '鼠狐猴',
#  '蓝顶蓝饰雀',
#  '龙鱼',
#  '王企鹅',
#  '蚁蜂',
#  '短尾猴',
#  '太平洋丽龟',
#  '美洲豹',
#  '面包虫',
#  '印度星龟',
#  '蝗虫',
#  '松鼠猴',
#  '东方剑齿象',
#  '达尔文树皮蜘蛛',
#  '大马哈鱼',
#  '原深茗荷',
#  '加州神鹫',
#  '剑齿虎',
#  '宽吻海豚',
#  '布氏幽蛙',
#  '金丝蛛',
#  '钳嘴鹳',
#  '白鳍豚',
#  '北美星鸦',
#  '飞鱼',
#  '星鼻鼹',
#  '海南长臂猿',
#  '蝰蛇',
#  '海狸鼠',
#  '三星盘虫',
#  '真涡虫',
#  '亚洲鲤鱼',
#  '虾蛄',
#  '树龙虾',
#  '卷尾猴',
#  '招潮蟹',
#  '灰狼',
#  '鲑鱼',
#  '黑水虻',
#  '观赏鱼',
#  '尖嘴地雀',
#  '针尾鸭',
#  '鸮鹦鹉',
#  '神仙鱼',
#  '清道夫',
#  '中原豫俊兽',
#  '猪鼻龟',
#  '斑纹隐小鳉',
#  '蛤蜊',
#  '丽鱼科鱼',
#  '奇异盗蛛',
#  '美国负鼠',
#  '猪鼻蛇',
#  '铃蟾',
#  '藤壶',
#  '枯叶蛙',
#  '大白鼠',
#  '食虫虻',
#  '胡狼',
#  '智利隐蛛',
#  '中国小鲵',
#  '火箭蛙',
#  '黄螺',
#  '叶蝇',
#  '蟹蛛',
#  '变色树蜥',
#  '栉龙',
#  '草原田鼠',
#  '皱鳃鲨',
#  '巴西涡螺',
#  '邓氏鱼',
#  '罗汉鱼',
#  '麝香猫',
#  '虹鳟鱼',
#  '姬鼠',
#  '鬣羚',
#  '植狡蛛',
#  '弓头鲸',
#  '角岛鲸',
#  '鳙鱼',
#  '美凤蝶',
#  '鲢鱼',
#  '郊狼',
#  '长吻海蛇',
#  '火蚁',
#  '斑点楔齿蜥',
#  '豺',
#  '崖燕',
#  '斗鱼',
#  '云豹',
#  '缺翅虫',
#  '吼猴',
#  '青鱼',
#  '缅甸蟒',
#  '大旋鳃虫',
#  '瘰螈',
#  '红背蜘蛛',
#  '大林猪',
#  '小䴙䴘',
#  '白胸苦恶鸟',
#  '鳕鱼',
#  '鼷鹿',
#  '香猪',
#  '长耳鸮',
#  '秋麒麟蟹蛛',
#  '袋獾',
#  '蛇獴',
#  '绿水蚺',
#  '沙丁鱼',
#  '伯劳',
#  '黄鼬',
#  '倭河马',
#  '非洲刺毛鼠',
#  '犀鸟',
#  '小丑鱼',
#  '埋葬虫',
#  '赤狐',
#  '竹节虫',
#  '乌桕大蚕蛾',
#  '垩鮨',
#  '壁蜂',
#  '面象虫',
#  '袋狼',
#  '绿孔雀',
#  '长鼻猴',
#  '北方象海豹',
#  '非洲草原象',
#  '黑象鼩',
#  '马来貘',
#  '日本猕猴',
#  '藏酋猴',
#  '凤蝶',
#  '大白鲨',
#  '侏鸬鹚',
#  '红颊獴',
#  '库班猪',
#  '鹿豚',
#  '卷毛野猪',
#  '须猪',
#  '红河猪',
#  '袋狮',
#  '红头黑林鸽',
#  '小笠原杂色林鸽',
#  '大蚁蛛',
#  '滑翔蚁',
#  '牙买加稻鼠',
#  '金线鲃',
#  '白足鼠',
#  '白腰文鸟',
#  '夜鹭',
#  '伊比利亚山蛙',
#  '山鸡细趾蟾',
#  '盲蛛',
#  '蚓螈',
#  '侏儒狨',
#  '条纹斑竹鲨',
#  '草蛉',
#  '鳄雀鳝',
#  '树蛙',
#  '王蛇',
#  '野骆驼',
#  '恐鸟',
#  '前口蝠鲼',
#  '豹纹鲨',
#  '墨西哥钝口螈',
#  '弓背蚁',
#  '虾虎鱼',
#  '海蜘蛛',
#  '阴虱',
#  '烟蛙',
#  '镰刀龙',
#  '大王乌贼',
#  '壮丽细尾鹩莺',
#  '椿象',
#  '鮟鱇',
#  '灰雁',
#  '黄金箭毒蛙',
#  '刀鱼',
#  '鱼龙',
#  '两头蛇',
#  '角蛙',
#  '红腹灰雀',
#  '蝠鲼',
#  '白鹳',
#  '黄金蟒',
#  '银背艾蛛',
#  '冰海精灵',
#  '三趾树懒',
#  '日本大山雀',
#  '寇蛛',
#  '彩蝠',
#  '孔雀',
#  '壶瓶山鮡',
#  '巨颊龙',
#  '长须鲸',
#  '江豚',
#  '雕齿兽',
#  '加拿大黑雁',
#  '越南棱皮树蛙',
#  '接吻鱼',
#  '小头鼠海豚',
#  '卷羽鹈鹕',
#  '刺肩蝽',
#  '田螺',
#  '沙虫',
#  '钩盲蛇',
#  '细尾鹩莺',
#  '叶水蚤',
#  '猛鲑',
#  '火燕',
#  '白鹭',
#  '振元龙',
#  '海鬣蜥',
#  '夜莺',
#  '利兹鱼',
#  '蠕虫',
#  '蝴蝶犬',
#  '貂',
#  '扁形虫',
#  '沙皮狗',
#  '咖啡果小蠹',
#  '食蜂鸟',
#  '虎纹伯劳鸟',
#  '斑头雁',
#  '黄鳝',
#  '三宝鸟',
#  '食蚊鱼',
#  '峨眉龙',
#  '荷兰侏儒兔',
#  '雪人蟹',
#  '鹰獒',
#  '黄蜂',
#  '狗鱼',
#  '大型蚤',
#  '海猴子',
#  '负子蟾蜍',
#  '对虾',
#  '云斑尖嘴丽鱼',
#  '虾',
#  '狮虎兽',
#  '非洲金豺',
#  '蛇鳄龟',
#  '尸鳖',
#  '龙虱',
#  '画眉鸟',
#  '小香猪',
#  '锦鲤',
#  '小黄鱼',
#  '巴西长髯卷尾猴',
#  '北岛垂耳鸦',
#  '三眼恐龙虾',
#  '北美旅鸽',
#  '华脐鱼',
#  '中华凤头燕鸥',
#  '棉尾兔',
#  '魔鬼蛙',
#  '怪诞虫',
#  '切蛋鱼',
#  '水滴鱼',
#  '阿根廷蚂蚁',
#  '斑嘴环企鹅',
#  '笑翠鸟',
#  '泥鳅',
#  '牛蛙',
#  '短尾矮袋鼠',
#  '红毛猩猩',
#  '蛾子',
#  '鳄龟',
#  '金枪鱼',
#  '华庭鸟',
#  '比索鸟',
#  '撒哈拉银蚁',
#  '鳐鱼',
#  '苏格兰折耳猫',
#  '树袋熊|考拉',
#  '东涛鸡',
#  '迅猛龙',
#  '兔狲',
#  '黇鹿',
#  '黑游蛇',
#  '赫摩里奥普雷斯毛虫',
#  '冥河龙',
#  '涡虫',
#  '叉尾卷尾鸟',
#  '双带扁蝇虎蜘蛛',
#  '五步蛇',
#  '野象',
#  '科罗拉多河蟾蜍',
#  '树袋熊',
#  '考拉',
#  '榛鸡',
#  '红狼',
#  '恐猫',
#  '大鳄龟',
#  '鲥鱼',
#  '栗冠弯嘴鹛',
#  '蓝极乐鸟',
#  '羊驼',
#  '奇虾',
#  '巨齿鲨',
#  '黄昏鸟',
#  '戴胜鸟',
#  '长喙龙',
#  '海王龙',
#  '小龙虾',
#  '帝王蟹',
#  '藏羚羊',
#  '中龙',
#  '金斑喙凤蝶',
#  '青头潜鸭',
#  '蜂猴',
#  '巢鼠',
#  '山雀',
#  '中华白海豚',
#  '马鬃蛇',
#  '蛇雕',
#  '黄腹水蛇',
#  '椰子螺',
#  '走鹃',
#  '丽星鹩鹛',
#  '高脚蛛',
#  '石龙子蜥蜴',
#  '鼬獾',
#  '绒山羊',
#  '恐狼',
#  '石斑鱼',
#  '大乌鞘蛇',
#  '印花蛇',
#  '大箭鱼',
#  '鮟鱇鱼',
#  '绿太阳鱼',
#  '狼鱼',
#  '翼龙',
#  '马蜂',
#  '旅鸟',
#  '蓝喉锯缘蜥',
#  '棱皮龟',
#  '雨燕',
#  '安邦雀鲷',
#  '云南盘鮈鱼',
#  '豆丁海马',
#  '猪鼻鼠',
#  '山魈',
#  '苏拉威西猕猴',
#  '海兔',
#  '留鸟',
#  '远古海狸兽',
#  '王锦蛇',
#  '黄粉虫',
#  '田凫',
#  '蠵龟',
#  '扬子鳄',
#  '鲳鱼',
#  '白鹇',
#  '金雕',
#  '凯门鳄',
#  '黑寡妇蜘蛛',
#  '切胸蚁',
#  '扁嘴海雀',
#  '非洲野狗',
#  '金蟾蜍',
#  '田鼠',
#  '九棘刺鱼',
#  '青斑蝶',
#  '金丝猴',
#  '巴西游走蛛',
#  '慈鲷',
#  '长耳跳鼠',
#  '姥鲨',
#  '锯腹脂鲤',
#  '北小麝鼩',
#  '巨蟹蛛',
#  '金丝燕',
#  '赤眼蜂',
#  '黑足雪貂',
#  '濑尿虾',
#  '洞螈',
#  '巨蜥',
#  '六不像',
#  '高黎贡羚牛',
#  '鬼面天蛾',
#  '沙漠雨蛙',
#  '格林胄蛙',
#  '长江江豚',
#  '巴西卷尾猴',
#  '三突花蛛',
#  '刻绒茧蜂',
#  '狮子鱼',
#  '斑驴',
#  '阿苏艾粗脚蟾蜍',
#  '甲龙',
#  '巴西龟',
#  '漏斗网蜘蛛',
#  '勺嘴鹬',
#  '血红龙鱼',
#  '黑鹳',
#  '七鳃鳗',
#  '蓝脸孔雀蜘蛛',
#  '钓鱼猫',
#  '棘冠海星',
#  '巴西胡峰',
#  '石鱼',
#  '海蛇',
#  '蛇头蝶',
#  '负子蝽',
#  '越中巨齿蛉',
#  '泡蟾',
#  '南非白纹牛羚',
#  '瓢虫茧蜂',
#  '非洲大蜗牛',
#  '金花蛇']

# %%
wv, u = buildWordVec(l)
# Out:
# 416 words are not in the model.
# D:\IDEs\Anaconda\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
u
# Out:
# ['斑胸草雀',
#  '伊犁鼠兔',
#  '倭黑猩猩',
#  '螳螂虾',
#  '裸鼹鼠',
#  '水熊虫',
#  '仙女虾',
#  '锯鳐',
#  '海蟾蜍',
#  '非洲肺鱼',
#  '黑脉金斑蝶',
#  '阳彩臂金龟',
#  '箭毒蛙',
#  '疣猪',
#  '锤头鲨',
#  '白犀牛',
#  '狼蛛',
#  '高鼻羚羊',
#  '月鱼',
#  '食骨蠕虫',
#  '帝王蝶',
#  '渡渡鸟',
#  '露脊鲸',
#  '中华锦绣龙虾',
#  '板足鲎',
#  '鹦鹉鱼',
#  '蜂鸟鹰蛾',
#  '墨西哥丽脂鲤',
#  '狨猴',
#  '栉水母',
#  '碎毛盘海蛞蝓',
#  '千足虫',
#  '双髻鲨',
#  '捕鱼蛛',
#  '独角鲸',
#  '帽贝',
#  '小蓝企鹅',
#  '行军蚁',
#  '雪貂',
#  '洞狮',
#  '须翡翠',
#  '切叶蚁',
#  '滇金丝猴',
#  '奇翼龙',
#  '六须鲶鱼',
#  '杜兹肺鱼',
#  '白颊林莺',
#  '蛇颈龙',
#  '土拔鼠',
#  '非洲灰鹦鹉',
#  '红点齿蟾',
#  '魟鱼',
#  '加拉帕戈斯象龟',
#  '赛加羚羊',
#  '攀鲈鱼',
#  '粉红珊瑚鳌虾',
#  '大王具足虫',
#  '小葵花凤头鹦鹉',
#  '弥曼始今鸟',
#  '白颊山雀',
#  '帆水母',
#  '斯瓦尔巴驯鹿',
#  '沙漠穹蛛',
#  '太平洋潜泥蛤',
#  '纽虫',
#  '四川短翅莺',
#  '放屁虫',
#  '啄羊鹦鹉',
#  '北美负鼠',
#  '射炮步甲',
#  '智利龙',
#  '绿鬣蜥',
#  '火玫瑰蜘蛛',
#  '口袋鲨',
#  '婆罗洲犀牛',
#  '震旦鸦雀',
#  '玻璃蛙',
#  '巨脉蜻蜓',
#  '鼓虾',
#  '大银鱼',
#  '鳞角腹足蜗牛',
#  '黑犀牛',
#  '白颏海燕',
#  '扁头摄魂蜂',
#  '中华花龟',
#  '桶水母',
#  '红嘴相思鸟',
#  '吸血蝙蝠',
#  '巨型蜘蛛蟹',
#  '跳蛛',
#  '齿猛蚁',
#  '蜜獾',
#  '毛丝鼠',
#  '陷阱颚蚁',
#  '颚口线虫',
#  '红树林树雀',
#  '高智商动物',
#  '布偶猫',
#  '羞死鸟',
#  '多鳍鱼',
#  '复变甲',
#  '螳水蝇',
#  '钩翅石蛾',
#  '旌蛉',
#  '蚊蝎蛉',
#  '普尔加托里猴',
#  '变形蛙',
#  '褐飞虱',
#  '果壳綦江龙',
#  '隐尾蠊',
#  '吸血鬼蟹',
#  '孔雀跳蛛',
#  '红色动物',
#  '透明鱼',
#  '沟齿鼩',
#  '安第斯眼镜熊',
#  '缅因猫',
#  '火体虫',
#  '南美洲栗鼠',
#  '奇异多指节蛙',
#  '冈比亚鼠',
#  '白头鹫',
#  '地中海实蝇',
#  '阿马乌童蛙',
#  '大角羊',
#  '假鳃鳉鱼',
#  '德国蜚蠊',
#  '美洲蜚蠊',
#  '刺背鳄蜥',
#  '兰花螳螂',
#  '短尾猫',
#  '新疆北鲵',
#  '突灶螽',
#  '燕八哥',
#  '穴居沙龟',
#  '田猫狸',
#  '查菲窄尾魟',
#  '苏格兰牧羊犬',
#  '安哥拉兔',
#  '加拉帕格斯巨人蜈蚣',
#  '枯叶蝴蝶',
#  '白色鼠海豚',
#  '隐翅虫',
#  '香港后棱蛇',
#  '白鹮',
#  '颌针鱼',
#  '鬣鳞蜥',
#  '科莫多巨蜥',
#  '虎皮鹦鹉',
#  '鼠狐猴',
#  '蓝顶蓝饰雀',
#  '蚁蜂',
#  '太平洋丽龟',
#  '印度星龟',
#  '东方剑齿象',
#  '达尔文树皮蜘蛛',
#  '原深茗荷',
#  '加州神鹫',
#  '宽吻海豚',
#  '布氏幽蛙',
#  '金丝蛛',
#  '钳嘴鹳',
#  '北美星鸦',
#  '星鼻鼹',
#  '海南长臂猿',
#  '三星盘虫',
#  '真涡虫',
#  '亚洲鲤鱼',
#  '树龙虾',
#  '招潮蟹',
#  '尖嘴地雀',
#  '针尾鸭',
#  '鸮鹦鹉',
#  '神仙鱼',
#  '中原豫俊兽',
#  '斑纹隐小鳉',
#  '丽鱼科鱼',
#  '奇异盗蛛',
#  '美国负鼠',
#  '猪鼻蛇',
#  '铃蟾',
#  '枯叶蛙',
#  '胡狼',
#  '智利隐蛛',
#  '中国小鲵',
#  '火箭蛙',
#  '叶蝇',
#  '蟹蛛',
#  '变色树蜥',
#  '栉龙',
#  '草原田鼠',
#  '皱鳃鲨',
#  '巴西涡螺',
#  '邓氏鱼',
#  '麝香猫',
#  '植狡蛛',
#  '弓头鲸',
#  '角岛鲸',
#  '美凤蝶',
#  '郊狼',
#  '长吻海蛇',
#  '火蚁',
#  '斑点楔齿蜥',
#  '崖燕',
#  '缺翅虫',
#  '吼猴',
#  '缅甸蟒',
#  '大旋鳃虫',
#  '瘰螈',
#  '红背蜘蛛',
#  '大林猪',
#  '小䴙䴘',
#  '白胸苦恶鸟',
#  '鼷鹿',
#  '香猪',
#  '长耳鸮',
#  '秋麒麟蟹蛛',
#  '袋獾',
#  '蛇獴',
#  '绿水蚺',
#  '倭河马',
#  '非洲刺毛鼠',
#  '埋葬虫',
#  '乌桕大蚕蛾',
#  '垩鮨',
#  '壁蜂',
#  '面象虫',
#  '袋狼',
#  '北方象海豹',
#  '非洲草原象',
#  '黑象鼩',
#  '马来貘',
#  '日本猕猴',
#  '侏鸬鹚',
#  '红颊獴',
#  '库班猪',
#  '鹿豚',
#  '卷毛野猪',
#  '须猪',
#  '红河猪',
#  '袋狮',
#  '红头黑林鸽',
#  '小笠原杂色林鸽',
#  '大蚁蛛',
#  '滑翔蚁',
#  '牙买加稻鼠',
#  '金线鲃',
#  '白足鼠',
#  '白腰文鸟',
#  '伊比利亚山蛙',
#  '山鸡细趾蟾',
#  '盲蛛',
#  '蚓螈',
#  '侏儒狨',
#  '条纹斑竹鲨',
#  '草蛉',
#  '鳄雀鳝',
#  '恐鸟',
#  '前口蝠鲼',
#  '墨西哥钝口螈',
#  '弓背蚁',
#  '虾虎鱼',
#  '海蜘蛛',
#  '烟蛙',
#  '镰刀龙',
#  '大王乌贼',
#  '壮丽细尾鹩莺',
#  '黄金箭毒蛙',
#  '角蛙',
#  '红腹灰雀',
#  '黄金蟒',
#  '银背艾蛛',
#  '冰海精灵',
#  '三趾树懒',
#  '日本大山雀',
#  '寇蛛',
#  '彩蝠',
#  '壶瓶山鮡',
#  '巨颊龙',
#  '雕齿兽',
#  '加拿大黑雁',
#  '越南棱皮树蛙',
#  '小头鼠海豚',
#  '卷羽鹈鹕',
#  '刺肩蝽',
#  '钩盲蛇',
#  '细尾鹩莺',
#  '叶水蚤',
#  '猛鲑',
#  '火燕',
#  '振元龙',
#  '海鬣蜥',
#  '扁形虫',
#  '沙皮狗',
#  '咖啡果小蠹',
#  '食蜂鸟',
#  '虎纹伯劳鸟',
#  '三宝鸟',
#  '荷兰侏儒兔',
#  '雪人蟹',
#  '鹰獒',
#  '大型蚤',
#  '负子蟾蜍',
#  '云斑尖嘴丽鱼',
#  '非洲金豺',
#  '蛇鳄龟',
#  '龙虱',
#  '巴西长髯卷尾猴',
#  '北岛垂耳鸦',
#  '三眼恐龙虾',
#  '北美旅鸽',
#  '华脐鱼',
#  '中华凤头燕鸥',
#  '棉尾兔',
#  '魔鬼蛙',
#  '怪诞虫',
#  '切蛋鱼',
#  '阿根廷蚂蚁',
#  '斑嘴环企鹅',
#  '短尾矮袋鼠',
#  '红毛猩猩',
#  '鳄龟',
#  '华庭鸟',
#  '比索鸟',
#  '撒哈拉银蚁',
#  '鳐鱼',
#  '苏格兰折耳猫',
#  '树袋熊|考拉',
#  '东涛鸡',
#  '兔狲',
#  '黇鹿',
#  '黑游蛇',
#  '赫摩里奥普雷斯毛虫',
#  '冥河龙',
#  '叉尾卷尾鸟',
#  '双带扁蝇虎蜘蛛',
#  '科罗拉多河蟾蜍',
#  '恐猫',
#  '大鳄龟',
#  '栗冠弯嘴鹛',
#  '蓝极乐鸟',
#  '奇虾',
#  '巨齿鲨',
#  '黄昏鸟',
#  '戴胜鸟',
#  '长喙龙',
#  '海王龙',
#  '金斑喙凤蝶',
#  '青头潜鸭',
#  '马鬃蛇',
#  '蛇雕',
#  '黄腹水蛇',
#  '椰子螺',
#  '走鹃',
#  '丽星鹩鹛',
#  '高脚蛛',
#  '石龙子蜥蜴',
#  '恐狼',
#  '大乌鞘蛇',
#  '印花蛇',
#  '大箭鱼',
#  '绿太阳鱼',
#  '狼鱼',
#  '蓝喉锯缘蜥',
#  '棱皮龟',
#  '安邦雀鲷',
#  '云南盘鮈鱼',
#  '豆丁海马',
#  '猪鼻鼠',
#  '苏拉威西猕猴',
#  '远古海狸兽',
#  '王锦蛇',
#  '田凫',
#  '蠵龟',
#  '黑寡妇蜘蛛',
#  '切胸蚁',
#  '扁嘴海雀',
#  '非洲野狗',
#  '金蟾蜍',
#  '九棘刺鱼',
#  '巴西游走蛛',
#  '慈鲷',
#  '长耳跳鼠',
#  '锯腹脂鲤',
#  '北小麝鼩',
#  '巨蟹蛛',
#  '黑足雪貂',
#  '濑尿虾',
#  '洞螈',
#  '六不像',
#  '高黎贡羚牛',
#  '鬼面天蛾',
#  '沙漠雨蛙',
#  '格林胄蛙',
#  '长江江豚',
#  '巴西卷尾猴',
#  '三突花蛛',
#  '刻绒茧蜂',
#  '狮子鱼',
#  '斑驴',
#  '阿苏艾粗脚蟾蜍',
#  '漏斗网蜘蛛',
#  '勺嘴鹬',
#  '血红龙鱼',
#  '蓝脸孔雀蜘蛛',
#  '钓鱼猫',
#  '棘冠海星',
#  '巴西胡峰',
#  '蛇头蝶',
#  '负子蝽',
#  '越中巨齿蛉',
#  '泡蟾',
#  '南非白纹牛羚',
#  '瓢虫茧蜂',
#  '非洲大蜗牛',
#  '金花蛇']

# %%
l
# Out:
# []

# %%
with open('./class/profs.txt') as f:
    fs = open('./class/profs_1.txt', 'w', encoding = 'utf-8')
    fs.write(f.readlines())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-36576da44143> in <module>()
#       1 with open('./class/profs.txt') as f:
#       2     fs = open('./class/profs_1.txt', 'w', encoding = 'utf-8')
# ----> 3     fs.write(f.readlines())
#
# TypeError: write() argument must be str, not list
